# %%
def make_beer_df():
    import pandas as pd
    cols = ['brewery_name', 'beer_name','beer_style','beer_beerid', 'beer_abv','review_overall',
            'review_taste','review_aroma', 'review_appearance', 'review_palate', ]
    #change path below
    df = pd.read_csv('beer_reviews.tar.gz',usecols=cols)
    df = df[['brewery_name', 'beer_name','beer_style','beer_beerid', 'beer_abv','review_overall',
             'review_taste','review_aroma', 'review_appearance', 'review_palate']]
#     df = df.rename(columns={'beer_beerid':'beer_id','beer_abv':'abv'})
    df.columns = ['brewery', 'beer','style','beer_id', 'abv','overall',
             'taste','aroma', 'appearance', 'palate']
    return df

def get_rid(df,cutoff=10):
    '''Get rid of beers with fewer than cutoff amount of reviews'''
    vc = df['beer_id'].value_counts().to_frame(name='count')
    beers_to_keep = list(vc[vc['count']>=cutoff].index)
    new = df[df.beer_id.isin(beers_to_keep)]
    return new

def rank(df,rank_var='overall'):
    ''' Rank the remaining beers by their mean overall rating '''
    rank = df.groupby(['brewery','beer','style','abv']).agg({'beer_id':'count',
                       'overall':'mean','taste':'mean','aroma':'mean',
                       'palate':'mean', 'appearance':'mean'}).sort_values(rank_var,ascending=False)
    rank = rank.rename(columns={'beer_id':'count'})
    return rank

def findrank(df,**kwargs):
    for item in kwargs.keys():
        df = df[df[item].str.contains(kwargs[item])].sort_values('overall',ascending=False)
    return df

# %%
def main():
    df = make_beer_df()
    new = get_rid(df,cutoff=35)
    rk = rank(df = new, rank_var='overall').reset_index()
    return rk

# %%
# if __name__ == '__main__':
#     main()
# Out:
#                                                 brewery  \
# 0                                   De Struise Brouwers
# 1                             Southampton Publick House
# 2                              Brouwerij Drie Fonteinen
# 3                                   Alpine Beer Company
# 4                              Brouwerij Drie Fonteinen
# 5                                        The Lost Abbey
# 6                              Brouwerij Drie Fonteinen
# 7                            Kern River Brewing Company
# 8                                   Brasserie Cantillon
# 9                                        The Lost Abbey
# 10                                        The Alchemist
# 11                        Russian River Brewing Company
# 12    Brouwerij Westvleteren (Sint-Sixtusabdij van W...
# 13                                Goose Island Beer Co.
# 14                        Russian River Brewing Company
# 15                               Hill Farmstead Brewery
# 16                             Founders Brewing Company
# 17                        Russian River Brewing Company
# 18                              Lawson's Finest Liquids
# 19                               FiftyFifty Brewing Co.
# 20                             Live Oak Brewing Company
# 21                        Russian River Brewing Company
# 22    Hair of the Dog Brewing Company / Brewery and ...
# 23                                   Portsmouth Brewery
# 24               Flossmoor Station Restaurant & Brewery
# 25                                Goose Island Beer Co.
# 26                                       The Lost Abbey
# 27                            Moonlight Brewing Company
# 28                              Närke Kulturbryggeri AB
# 29                                           The Bruery
# ...                                                 ...
# 6246                          Green's Gluten Free Beers
# 6247                                 Miller Brewing Co.
# 6248                              Coors Brewing Company
# 6249                       Indian Wells Brewing Company
# 6250        Brasserie Fischer / Fischer Biere d' Alsace
# 6251                                     Anheuser-Busch
# 6252                                Latrobe Brewing Co.
# 6253                                     Anheuser-Busch
# 6254                             Bavaria Brouwerij N.V.
# 6255                           Sprecher Brewing Company
# 6256                                     Anheuser-Busch
